# %%
import sys
import os
from pathlib import Path

# Add the src folder to Python path
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))  # notebooks/ -> repo root
sys.path.append(os.path.join(repo_root, "src"))

# %%
import pandas as pd

from sklearn.model_selection import GridSearchCV
from DataManagement import DataHandler, DefaultDataHandler, ImprovedDataHandler,DataViewer
from ModelPipelines import DefaultPipeline, XGBoostSurvivalPipeline
from sksurv.util import Surv
from config import PARAMS_RSF, PARAMS_XGB
from sksurv.metrics import concordance_index_ipcw,concordance_index_censored
import logging
import os
import numpy as np
from LearningCurve import learning_curve_analysis, RiskScorePlotter
from GridSearch import ModelSelection

# %%
# prepare loading
repo_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
clinical_path = os.path.join(repo_root, "data", "raw", "X_train", "clinical_train.csv")
molecular_path = os.path.join(repo_root, "data", "raw", "X_train", "molecular_train.csv")
target_path = os.path.join(repo_root, "data", "raw", "target_train.csv")

# Load data
df = pd.read_csv(clinical_path, index_col=0)
maf_df = pd.read_csv(molecular_path, index_col=0)
target_df = pd.read_csv(target_path, index_col=0)

# %%
# first let's plot some graphs on initial data
# let's aggregate the info into one Dataframe

joined_initial_data = df.merge(maf_df, left_index=True, right_index=True, how='left')
joined_initial_data = joined_initial_data.drop(columns=['START', 'END'])
# for the molecular data
dtm = DataViewer(joined_initial_data, target_df)

# first let's plot the analysis in terms of missing data....
dtm.stats_analysis().head(25)
# Out:
#                   dtype  count_nan  nan_percentage  distinct_values    count  \
# CENTER           object          0        0.000000               23    11232
# BM_BLAST        float64        420        3.739316              139  10812.0
# WBC             float64        939        8.360043              699  10293.0
# ANC             float64        685        6.098647             1026  10547.0
# MONOCYTES       float64       2049       18.242521              609   9183.0
# HB              float64        382        3.400997              239  10850.0
# PLT             float64        434        3.863960              586  10798.0
# CYTOGENETICS     object       1408       12.535613             1194     9824
# CHR              object        411        3.659188               23    10821
# REF              object        411        3.659188              406    10821
# ALT              object        411        3.659188              332    10821
# GENE             object        297        2.644231              124    10935
# PROTEIN_CHANGE   object        309        2.751068             4686    10923
# EFFECT           object        297        2.644231               16    10935
# VAF             float64        386        3.436610             2952  10846.0
# DEPTH           float64        411        3.659188             2268  10821.0
#
#                        mean         std   min       25%      50%     75%  \
# CENTER                  NaN         NaN   NaN       NaN      NaN     NaN
# BM_BLAST           6.851878    8.169294   0.0       2.0      4.0    10.0
# WBC                7.808363   12.895303   0.2       2.7      4.2    7.21
# ANC                3.799921    6.793446   0.0       1.0      2.0     4.0
# MONOCYTES          1.343019     3.49102   0.0      0.15      0.4     1.0
# HB                 9.835244    2.035172   4.0      8.48    9.666    11.1
# PLT              158.834572  152.570387   2.0      61.0    114.0   209.0
# CYTOGENETICS            NaN         NaN   NaN       NaN      NaN     NaN
# CHR                     NaN         NaN   NaN       NaN      NaN     NaN
# REF                     NaN         NaN   NaN       NaN      NaN     NaN
# ALT                     NaN         NaN   NaN       NaN      NaN     NaN
# GENE                    NaN         NaN   NaN       NaN      NaN     NaN
# PROTEIN_CHANGE          NaN         NaN   NaN       NaN      NaN     NaN
# EFFECT                  NaN         NaN   NaN       NaN      NaN     NaN
# VAF                0.305087    0.211524  0.02  0.102625  0.32125   0.442
# DEPTH           1051.229554  552.861902  16.0     660.0    975.0  1353.0
#
#                    max
# CENTER             NaN
# BM_BLAST          91.0
# WBC              154.4
# ANC             109.62
# MONOCYTES         44.2
# HB                16.6
# PLT             1451.0
# CYTOGENETICS       NaN
# CHR                NaN
# REF                NaN
# ALT                NaN
# GENE               NaN
# PROTEIN_CHANGE     NaN
# EFFECT             NaN
# VAF              0.999
# DEPTH           7156.0

# %%
# now, the correlation matrix between the numerical features
dtm.plot_correlation_matrix()

# %%
# now the distribution of the numerical variables
dtm.plot_float_distributions()

# %%
dtm.plot_categorical_boxplot(["CENTER"])

# %%
# pipeline

    # Build and fit pipeline
data_handler = ImprovedDataHandler(df, maf_df, target_df)
prepared_data = data_handler.prepare()
pipeline_builder = DefaultPipeline(prepared_data)
pipeline = pipeline_builder.build_pipeline()

train_cols = prepared_data[0].columns.tolist()

    # transform the target data
y_surv = Surv.from_dataframe(
    event='OS_STATUS',   # 1 = event, 0 = censored
    time='OS_YEARS',
    data=prepared_data[1]
)
pipeline
# Out:
# Pipeline(steps=[('drop_missing', DropMissingTransformer()),
#                 ('column_transformer',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('num',
#                                                   Pipeline(steps=[('impute_num',
#                                                                    SimpleImputer(strategy='median'))]),
#                                                   ['BM_BLAST', 'WBC', 'ANC',
#                                                    'MONOCYTES', 'HB', 'PLT',
#                                                    'cyto_normal',
#                                                    'cyto_complex', 'monosomy_7',
#                                                    'trisomy_8', 'del_5q',
#                                                    't_3_3', 'n_abnormalities',
#                                                    'cyto...
#                                                                                  sparse_output=False)),
#                                                                   ('impute_cat',
#                                                                    KNNImputer(weights='distance'))]),
#                                                   ['CENTER']),
#                                                  ('binary_cat',
#                                                   Pipeline(steps=[('impute_cat',
#                                                                    KNNImputer(weights='distance'))]),
#                                                   ['cyto_normal',
#                                                    'cyto_complex', 'monosomy_7',
#                                                    'trisomy_8', 'del_5q',
#                                                    't_3_3', 'cyto_mosaic'])])),
#                 ('feature_ratios', FeatureRatioCreator()),
#                 ('model', RandomSurvivalForest(n_jobs=-1, random_state=42))])

# %%
#example of the transformation made on cytogenetics
print("Initial CYTOGENETICS column:")
df.loc[["P117425", "P117426", "P117437", "P105454", "P132707"],["CYTOGENETICS"]].head()
# Out:
# Initial CYTOGENETICS column:
#                                               CYTOGENETICS
# ID
# P117425  46,xx,del(5)(q14q34),del(8)(q21q23)[6]/44-45,x...
# P117426                                              46,xx
# P117437  45,xx,der(4)del(4)(p13p15)del(4)(q23q26)der(5;...
# P105454  44,xx,del(4)(p),del(5)(q13q33),der(7q),+8,add(...
# P132707                                            complex

# %%
print("Transformation:")
prepared_data[0].loc[
    ["P117425", "P117426", "P117437", "P105454", "P132707"],
    ['cyto_normal', 'cyto_complex', 'monosomy_7', 'trisomy_8', 'del_5q', 't_3_3', 'cyto_mosaic']
].head()
# Out:
# Transformation:
#          cyto_normal  cyto_complex  monosomy_7  trisomy_8  del_5q  t_3_3  \
# ID
# P117425            0             0           1          0       1      0
# P117426            1             0           0          0       0      0
# P117437            0             0           0          0       0      0
# P105454            0             0           0          1       1      0
# P132707            0             1           0          0       0      0
#
#          cyto_mosaic
# ID
# P117425            1
# P117426            0
# P117437            1
# P105454            0
# P132707            0

# %%
#example of the transformation made on genes

print("Initial Genes column:")
maf_df.loc[["P117425", "P117426", "P117437", "P105454", "P132707"],["GENE","VAF"]].head(50)
# Out:
# Initial Genes column:
#            GENE     VAF
# ID
# P117425  DNMT3A  0.0330
# P117425    TP53  0.2130
# P117425  DNMT3A  0.3026
# P117426   DDX23  0.0270
# P117426   SF3B1  0.3010
# P117426     MLL     NaN
# P117437    TET2  0.5860
# P117437    TP53  0.4000
# P105454    TP53  0.8490
# P105454  DNMT3A  0.4530
# P132707    TP53  0.6900

# %%
print("Transformation:")
prepared_data[0].loc[
    ["P117425", "P117426", "P117437", "P105454", "P132707"],
    ['DNMT3A', 'TP53', 'DDX23', 'SF3B1', 'MLL', 'TET2', 'TP53']
].head()
# Out:
# Transformation:
#          DNMT3A   TP53  DDX23  SF3B1  MLL   TET2   TP53
# ID
# P117425  0.3356  0.213  0.000  0.000  0.0  0.000  0.213
# P117426  0.0000  0.000  0.027  0.301  0.0  0.000  0.000
# P117437  0.0000  0.400  0.000  0.000  0.0  0.586  0.400
# P105454  0.4530  0.849  0.000  0.000  0.0  0.000  0.849
# P132707  0.0000  0.690  0.000  0.000  0.0  0.000  0.690

# %%
# gridsearch
# first, we will train our model on a random survival forest

grid_search = ModelSelection(model=pipeline, param_grid=PARAMS_RSF, cv=5)
grid_search.fit(prepared_data[0], y_surv)
print("Best Parameters:", grid_search.best_params())    
print("Best Score:", grid_search.best_score())
# Out:
# 2026-03-18 15:07:35,102 - INFO - Initialized ModelSelection with model: Pipeline, cv: 5, n_jobs: -1
# 2026-03-18 15:07:35,104 - INFO - Starting Grid Search with 4 combinations
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=100; total time=   9.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=100; total time=  10.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=100; total time=  10.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=100; total time=  10.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=100; total time=  10.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=200; total time=  19.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=200; total time=  19.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=100; total time=   9.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=200; total time=  20.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=100; total time=   9.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=100; total time=  10.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=200; total time=  19.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=10, model__n_estimators=200; total time=  18.8s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=100; total time=   9.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=100; total time=   9.8s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100; total time=  10.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100; total time=  11.1s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100; total time=  13.1s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=200; total time=  24.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=200; total time=  24.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=200; total time=  26.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=200; total time=  25.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100; total time=  19.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=100; total time=  18.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=5, model__min_samples_split=20, model__n_estimators=200; total time=  31.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200; total time=  24.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200; total time=  25.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200; total time=  25.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200; total time=  28.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=100; total time=  14.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=10, model__n_estimators=200; total time=  27.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=100; total time=  14.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=100; total time=  14.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=100; total time=   9.5s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=100; total time=   9.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=100; total time=   5.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=100; total time=   5.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=100; total time=   6.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=100; total time=   6.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=200; total time=  15.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=200; total time=  14.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=200; total time=  15.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=200; total time=  15.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=10, model__min_samples_split=20, model__n_estimators=200; total time=  15.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=100; total time=   5.9s
# /Users/a33619/Leukemia-Survival-Rate/.venv-2/lib/python3.14/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=100; total time=   4.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=100; total time=   5.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=200; total time=   9.8s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=200; total time=  10.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=200; total time=   9.8s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=200; total time=  10.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=10, model__n_estimators=200; total time=   9.5s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=100; total time=   5.1s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=100; total time=   5.5s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=100; total time=   4.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=100; total time=   5.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=200; total time=  10.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=200; total time=  11.1s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=100; total time=   5.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=100; total time=   7.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=200; total time=  12.1s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=200; total time=  12.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=20, model__min_samples_split=20, model__n_estimators=200; total time=  12.2s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=100; total time=   5.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=100; total time=   5.4s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=100; total time=   5.5s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=100; total time=   5.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=200; total time=   9.5s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=100; total time=   5.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=200; total time=   9.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=200; total time=   8.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=200; total time=   9.7s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=10, model__n_estimators=200; total time=   9.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=100; total time=   4.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=100; total time=   4.6s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=200; total time=   7.0s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=200; total time=   7.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=200; total time=   6.9s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=200; total time=   6.3s
# [CV] END model__max_features=sqrt, model__min_samples_leaf=40, model__min_samples_split=20, model__n_estimators=200; total time=   5.6s
# Best Parameters: {'model__max_features': 'sqrt', 'model__min_samples_leaf': 5, 'model__min_samples_split': 20, 'model__n_estimators': 200}
# Best Score: 0.7324195476258927

# %%
# now, let's plot the learning curve to make sure we don't overfit

learning_curve_analysis(pipeline, prepared_data[0], y_surv, PARAMS_RSF)
# Out:
# 2026-03-18 15:09:50,653 - INFO - Start looping ...
# 2026-03-18 15:09:50,654 - INFO - Iteration : 0.1
# 2026-03-18 15:09:57,172 - INFO - Iteration : 0.26
# 2026-03-18 15:10:10,922 - INFO - Iteration : 0.42000000000000004
# 2026-03-18 15:10:39,967 - INFO - Iteration : 0.58
# 2026-03-18 15:11:33,189 - INFO - Iteration : 0.74
# 2026-03-18 15:12:42,499 - INFO - Iteration : 0.9
# /Users/a33619/Leukemia-Survival-Rate/.venv-2/lib/python3.14/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/a33619/Leukemia-Survival-Rate/src/LearningCurve.py:107: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.lineplot(

# %%
# we don't seem to overfit, no problems of overfitting

# %%
# plot a few graphs on the risk score / predicted survival...

# first the predicted risk score distribution
best_model=grid_search.best_model
print("Loading Scores...")    
plotter = RiskScorePlotter(model=best_model, X=prepared_data[0], y=y_surv)
print("Done.")
plotter.plot_overall_distribution()
# Out:
# Loading Scores...
# Done.

# %%
# first distribution of survival prediction per event (0 or 1)
plotter.plot_by_event_status()

# %%
# plot kaplan meyer curve
plotter.plot_kaplan_meier()

# %%
# now, we will test trainig our model on a xgboost

# pipeline

    # Build and fit pipeline
data_handler = ImprovedDataHandler(df, maf_df, target_df)
prepared_data = data_handler.prepare()
pipeline_builder = XGBoostSurvivalPipeline(prepared_data)
pipeline = pipeline_builder.build_pipeline()

train_cols = prepared_data[0].columns.tolist()

    # transform the target data
y_surv = Surv.from_dataframe(
    event='OS_STATUS',   # 1 = event, 0 = censored
    time='OS_YEARS',
    data=prepared_data[1]
)

# gridsearch
grid_search = ModelSelection(model=pipeline, param_grid=PARAMS_XGB, cv=5)
grid_search.fit(prepared_data[0], y_surv)
print("Best Parameters:", grid_search.best_params())    
print("Best Score:", grid_search.best_score())
# Out:
# 2026-03-18 15:14:34,674 - INFO - Initialized ModelSelection with model: Pipeline, cv: 5, n_jobs: -1
# 2026-03-18 15:14:34,675 - INFO - Starting Grid Search with 6 combinations
# Fitting 5 folds for each of 32 candidates, totalling 160 fits
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.3s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.2s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=0.7, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   2.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   2.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   2.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   2.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   2.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   2.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   2.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   2.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   2.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   2.2s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.01, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   2.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.6s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.4s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=3, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.3s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=0.5, model__subsample=1.0; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   2.0s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=0.8; total time=   1.9s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   2.1s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.7s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.5s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.8s
# [CV] END model__colsample_bytree=1.0, model__learning_rate=0.03, model__max_depth=4, model__n_estimators=500, model__reg_lambda=1.0, model__subsample=1.0; total time=   1.6s
# Best Parameters: {'model__colsample_bytree': 1.0, 'model__learning_rate': 0.01, 'model__max_depth': 4, 'model__n_estimators': 500, 'model__reg_lambda': 1.0, 'model__subsample': 0.8}
# Best Score: 0.736853388491728

# %%
# score looks lower, let's plot curve anyway

# now, let's plot the learning curve to make sure we don't overfit

learning_curve_analysis(pipeline, prepared_data[0], y_surv, PARAMS_XGB)
# Out:
# 2026-03-18 15:15:08,514 - INFO - Start looping ...
# 2026-03-18 15:15:08,516 - INFO - Iteration : 0.1
# 2026-03-18 15:15:30,012 - INFO - Iteration : 0.26
# 2026-03-18 15:15:57,814 - INFO - Iteration : 0.42000000000000004
# 2026-03-18 15:16:32,299 - INFO - Iteration : 0.58
# 2026-03-18 15:17:10,950 - INFO - Iteration : 0.74
# 2026-03-18 15:18:11,385 - INFO - Iteration : 0.9
# /Users/a33619/Leukemia-Survival-Rate/src/LearningCurve.py:107: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.lineplot(

# %%
# learning curve doesn't overfit but isn't as good as before

# %%
# plot risk scores for patients (first, risk score distribution
best_model=grid_search.best_model
print("Loading Scores...")
plotter = RiskScorePlotter(model=best_model, X=prepared_data[0], y=y_surv)
print("Done.")
plotter.plot_overall_distribution()
# Out:
# Loading Scores...
# Done.

# %%
# first distribution of survival prediction per event (0 or 1)
plotter.plot_by_event_status()

# %%
# distribution isn't as differenciated by status, proves again it's not as good as the RSF

# %%
# plot kaplan meyer curve
plotter.plot_kaplan_meier()
